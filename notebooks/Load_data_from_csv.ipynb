# %%
import graphlab as gl

# %% [markdown]
# # Reading The CSV Files

# %%
papersSF = gl.SFrame.read_csv('../data/csvData/papers.csv', error_bad_lines=True,
                             column_type_hints = {'PaperID' : int,
                                                  'Date': int,
                                                  'Pages': int})
papersSF
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-18024 - Server binary: /Library/Python/2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1402441150.log
# [INFO] GraphLab Server Version: 0.3.1216
# Columns:
# 	PaperID	int
# 	Title	str
# 	Author	str
# 	Date	int
# 	Abstract	str
# 	Pages	int
# 	Venue	str
# 	Email	str
# 	Email Name	str
#
# Rows: 2
#
# Data:
#    PaperID                                              Title  \
# 0  9506048  Addendum to the paper Combinatorics of the mod...
# 1  9201056  Algebraic Structures and Differential Geometry...
#
#                               Author  Date  \
# 0        C. Itzykson and J.-B. Zuber  1992
# 1  Edward Witten and Barton Zwiebach  1992
#
#                                             Abstract  Pages Venue  \
# 0  Addendum to the paper Combinatorics of the Mod...      3
# 1  A careful treatment of closed strin BRST cohom...     65
#
#                                        Email          Email Name
# 0               zuber@poseidon.saclay.cea.fr  Jean-Bernard Zuber
# 1  ZWIEBACH%IASSNS.BITNET@pucc.princeton.edu
#
# [2 rows x 9 columns]

# %%
citationSF = gl.SFrame.read_csv('../data/csvData/hep-th-citations.csv',
                                delimiter = " ",
                                column_type_hints = {'SourceID' : int,
                                                     'TargetID' : int})
citationSF
# Out:
# Columns:
# 	SourceID	int
# 	TargetID	int
#
# Rows: 352807
#
# Data:
#    SourceID  TargetID
# 0      1001   9304045
# 1      1001   9308122
# 2      1001   9309097
# 3      1001   9311042
# 4      1001   9401139
# 5      1001   9404151
# 6      1001   9407087
# 7      1001   9408099
# 8      1001   9501030
# 9      1001   9503124
#
# ...
# [352807 rows x 2 columns]

# %% [markdown]
# # Creating The SGraph

# %%
paperPaperSG = gl.SGraph()
paperPaperSG = paperPaperSG.add_vertices(vertices=papersSF, vid_field='PaperID')
paperPaperSG = paperPaperSG.add_edges(edges=citationSF, src_field='SourceID', dst_field='TargetID')

# %%
paperPaperSG.get_edges().to_dataframe()
# Out:
#     __src_id  __dst_id
# 0    9812103   9403056
# 1    9812103   9412180
# 2    9812127   9204102
# 3    9812127   9711067
# 4    9812127   9809187
# 5    9812131   9204044
# 6    9812131   9208047
# 7    9812153   9709148
# 8    9812190   9212009
# 9    9812190   9309128
# 10   9812190   9512179
# 11   9812194   9804035
# 12   9812194   9805082
# 13   9812194   9805105
# 14   9812194   9805145
# 15   9812194   9808184
# 16   9812194   9811060
# 17   9812213   9809053
# 18   9812216   9809164
# 19   9812216   9812027
# 20   9812216   9812062
# 21   9812224   9706117
# 22   9812224   9712004
# 23   9812224   9712086
# 24   9812224   9806169
# 25   9901012   9604089
# 26   9901012   9709108
# 27   9901012   9802042
# 28   9901017   9701048
# 29   9901017   9707208
# 30   9901017   9802148
# 31   9901017   9807079
# 32   9901054   9302047
# 33   9901054   9503095
# 34   9901054   9706120
# 35   9901063   9611038
# 36   9901066   9205027
# 37   9901066   9809139
# 38   9901087   9512184
# 39   9901087   9607104
# 40   9901089   9611042
# 41   9901089   9804027
# 42   9901091   9711090
# 43   9901091   9812025
# 44   9901108   9409080
# 45   9901113   9607198
# 46   9901126   9704145
# 47   9901131   9310197
# 48   9901150   9408099
# 49   9901150   9504129
# 50   9901152   9704197
# 51   9901152   9709063
# 52   9901152   9801183
# 53   9901152   9801189
# 54   9901152   9806082
# 55   9901152   9811037
# 56   9901154   9712028
# 57   9902002   9709035
# 58   9902018   9408099
# 59   9902018   9506098
#          ...       ...
#
# [352807 rows x 2 columns]

# %%
papersSF.save('../data/glData/papersSF_org')
citationSF.save('../data/glData/citationsSF_org')
paperPaperSG.save('../data/glData/paperPaperSG_org')
