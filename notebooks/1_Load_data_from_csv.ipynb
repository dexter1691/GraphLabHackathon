# %%
import graphlab as gl

# %% [markdown]
# # Reading The CSV Files

# %%
papersSF = gl.SFrame.read_csv('../data/csvData/abstract_data.csv', error_bad_lines=False,
                              delimiter = "\t",
                              na_values = ['N/A'],
                              column_type_hints = {'ID' : int,
                                                  'Year': int,
                                                  'Pages': int})
papersSF
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-27485 - Server binary: /Users/sfakhraei/venv/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1402529923.log
# [INFO] GraphLab Server Version: 0.3.1216
# Columns:
# 	ID	int
# 	Title	str
# 	Authors	str
# 	Year	int
# 	Abstract	str
# 	Email	str
# 	Pages	int
# 	Venue	str
# 	EmailName	str
#
# Rows: 29548
#
# Data:
#         ID                                              Title  \
# 0  9201001  Combinatorics of the Modular Group II: the Kon...
# 1  9201002  Inomogeneous Quantum Groups as Symmetries of P...
# 2  9201003  Intersection Theory, Integrable Hierarchies an...
# 3  9201004  The Heterotic Green-Schwarz Superstring on an ...
# 4  9201005   Ward Identities in Two-Dimensional String Theory
# 5  9201006   On Symmetries of Some Massless 2D Field Theories
# 6  9201007            Static Domain Walls in N=1 Supergravity
# 7  9201008  Coulomb Gas Representations and Screening Oper...
# 8  9201009           Large-Small Equivalence in String Theory
# 9  9201010  From Virasoro Constraints in Kontsevich's Mode...
#
#                                              Authors  Year  \
# 0                        C. Itzykson and J.-B. Zuber  1992
# 1  F.Bonechi, E.Celeghini, R.Giachetti, E.Sorace ...  1992
# 2                                  Robbert Dijkgraaf  1992
# 3                                   Nathan Berkovits  1992
# 4                                   Igor R. Klebanov  1992
# 5                                      Denis Bernard  1992
# 6      Mirjam Cvetic, Stephen Griffies, Soo-Jong Rey  1992
# 7                                    Satoshi Matsuda  1992
# 8                                    Eva Silverstein  1992
# 9               A.Marshakov, A.Mironov and A.Morozov  1992
#
#                                             Abstract  \
# 0  We study algebraic aspects of Kontsevich integ...
# 1  The quantum deformed (1+1) Poincare' algebra i...
# 2  In these lecture notes we review the various r...
# 3  By defining the heterotic Green-Schwarz supers...
# 4  I study the Ward identities of the symmetry of...
# 5  We describe few aspects of the quantum symmetr...
# 6  We study supersymmetric domain walls in N=1 su...
# 7  The Coulomb gas representations are presented ...
# 8  The simplest toroidally compactified string th...
# 9  The Ward identities in Kontsevich-like 1-matri...
#
#                            Email  Pages             Venue EmailName
# 0   zuber@poseidon.saclay.cea.fr     46   Int.J.Mod.Phys.      None
# 1                           None      5    Phys.Rev.Lett.      None
# 2                           None     73              None      None
# 3  nathan@max.physics.sunysb.edu     33        Nucl.Phys.      None
# 4                           None     12  Mod. Phys. Lett.      None
# 5                           None     13        Phys.Lett.      None
# 6                           None     29        Nucl.Phys.      None
# 7                           None     16        Phys.Lett.      None
# 8      THEORY@HUHEPL.HARVARD.EDU     12       Phys. Lett.      None
# 9                           None     13  Mod. Phys. Lett.      None
#
# ...
# [29548 rows x 9 columns]

# %%
citationSF = gl.SFrame.read_csv('../data/csvData/hep-th-citations.csv',
                                delimiter = " ",
                                column_type_hints = {'SourceID' : int,
                                                     'TargetID' : int})
citationSF
# Out:
# Columns:
# 	SourceID	int
# 	TargetID	int
#
# Rows: 352807
#
# Data:
#    SourceID  TargetID
# 0      1001   9304045
# 1      1001   9308122
# 2      1001   9309097
# 3      1001   9311042
# 4      1001   9401139
# 5      1001   9404151
# 6      1001   9407087
# 7      1001   9408099
# 8      1001   9501030
# 9      1001   9503124
#
# ...
# [352807 rows x 2 columns]

# %% [markdown]
# # Creating The SGraph

# %%
paperPaperSG = gl.SGraph()
paperPaperSG = paperPaperSG.add_vertices(vertices=papersSF, vid_field='ID')
paperPaperSG = paperPaperSG.add_edges(edges=citationSF, src_field='SourceID', dst_field='TargetID')

# %%
paperPaperSG.get_edges().to_dataframe()
# Out:
#     __src_id  __dst_id
# 0     206151    107143
# 1     206151    203217
# 2     206154      2159
# 3     206154    104069
# 4     206154    107143
# 5     206154    108226
# 6     206154    109025
# 7     206154    111198
# 8     206154    203060
# 9     206154    203217
# 10    206154   9911096
# 11    206173   9205043
# 12    206173   9606104
# 13    206173   9612103
# 14    206173   9803063
# 15    206173   9911242
# 16    206196    104238
# 17    206196    201185
# 18    206196   9411198
# 19    206214      1024
# 20    206214     11261
# 21    206214    112206
# 22    206214    201081
# 23    206214    202021
# 24    206214   9512153
# 25    206214   9905196
# 26    206214   9908142
# 27    206214   9910159
# 28    206217    111207
# 29    206219   9911174
# 30    206236    112237
# 31    206238    108100
# 32    206240   9301001
# 33    207003    105008
# 34    207003    203020
# 35    207005      3074
# 36    207005    104020
# 37    207005   9602070
# 38    207005   9603133
# 39    207009      1192
# 40    207009      7064
# 41    207009    202140
# 42    207009   9803131
# 43    207023   9410212
# 44    207023   9608034
# 45    207026   9503124
# 46    207026   9510173
# 47    207026   9708130
# 48    207028    108040
# 49    207028   9205012
# 50    207044    102076
# 51    207044    105059
# 52    207044    111129
# 53    207044    203188
# 54    207044    205218
# 55    207044   9908142
# 56    207049   9708030
# 57    207068    109075
# 58    207068   9407134
# 59    207068   9408133
#          ...       ...
#
# [352807 rows x 2 columns]

# %% [markdown]
# # Cleaning the pages

# %%
papersSF['Pages'].apply(lambda x : None if x > 1000 else x)
# Out:
# dtype: int
# Rows: 29548
# [46, 5, 73, 33, 12, 13, 29, 16, 12, 13, 14, 33, 67, 16, 12, 17, 16, 25, 14, 33, 18, 10, 10, 8, 6, 60, 15, 14, 14, 24, 11, 9, 13, 34, 16, 40, 15, 18, None, 72, 46, 7, 11, 8, 9, 17, None, None, 22, 28, 29, 11, 14, 13, 3, 65, 54, 9, 100, 26, 26, 21, 9, 23, 26, 10, 38, 5, 12, None, 15, 11, 20, 10, 24, 44, 18, 72, 42, 40, 17, 42, 10, 31, 19, 12, 53, 22, 25, 14, 31, 19, 11, 39, 12, 16, 10, 23, 38, 13, ... ]

# %%
papersSF.save('../data/glData/papersSF_org')

# %%
citationSF.save('../data/glData/citationsSF_org')

# %%
paperPaperSG.save('../data/glData/paperPaperSG_org')
